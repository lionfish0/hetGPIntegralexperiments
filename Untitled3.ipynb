# %%
import pandas as pd
df = pd.read_csv('sheffield_houseprices.csv')
for p in df['postcode']: print(p)
# Out:
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AA
# S11 8AE
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AL
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AN
# S11 8AP
# S11 8AP
# S11 8AP
# S11 8AP
# S11 8AP
# S11 8AP
# S11 8AP
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# S11 8AQ
# ...

# %%
'S1  4EY'
'S1 4EY'

# %%
from dp4gp.datasets import load_postcode, load_pricepaid

# %%
since = 2000

pp = load_pricepaid()
pc = load_postcode()
# Out:
# Loading price data.
# Using presampled dataset.
# Loaded property prices.

# %%
pp['postcode'][0] = "S1   1A"
# Out:
# /home/mike/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pp['postcode'] = pp['postcode'].str.replace(' ','')
pc['postcode'] = pc['postcode'].str.replace(' ','')

# %%
pc['postcode']
# Out:
# 0       ZE10AA
# 1       ZE10AB
# 2       ZE10AD
# 3       ZE10AE
# 4       ZE10AF
# 5       ZE10AG
# 6       ZE10AH
# 7       ZE10AJ
# 8       ZE10AL
# 9       ZE10AN
# 10      ZE10AP
# 11      ZE10AQ
# 12      ZE10AR
# 13      ZE10AS
# 14      ZE10AT
# 15      ZE10AU
# 16      ZE10AW
# 17      ZE10AX
# 18      ZE10AZ
# 19      ZE10BA
# 20      ZE10BB
# 21      ZE10BD
# 22      ZE10BE
# 23      ZE10BF
# 24      ZE10BG
# 25      ZE10BH
# 26      ZE10BJ
# 27      ZE10BL
# 28      ZE10BN
# 29      ZE10BP
#          ...
# 6177    LU79QX
# 6178    LU79QY
# 6179    LU79QZ
# 6180    LU79RA
# 6181    LU79RB
# 6182    LU79RD
# 6183    LU79RG
# 6184    LU79RH
# 6185    LU79RL
# 6186    LU79RN
# 6187    LU79RP
# 6188    LU79RQ
# 6189    LU79RX
# 6190    LU79RY
# 6191    LU79RZ
# 6192    LU79SA
# 6193    LU79SB
# 6194    LU79SD
# 6195    LU79SE
# 6196    LU79SF
# 6197    LU79SG
# 6198    LU79SH
# 6199    LU79SJ
# 6200    LU79SP
# 6201    LU79SQ
# 6202    LU79WB
# 6203    LU79XH
# ...

# %%
list(pp['postcode'])
# Out:
# ['TQ1 1RY',
#  'L26 7XJ',
#  'BH12 2AE',
#  'IP13 0DR',
#  'WS14 0BE',
#  'S42 5GA',
#  'KT17 2DU',
#  'WS10 9LD',
#  'KT11 1HP',
#  'WF6 2TT',
#  'NR17 1EY',
#  'OX17 1JU',
#  'TF2 9NW',
#  'CW12 3DG',
#  'BH1 1QY',
#  'SM6 7AG',
#  'BD6 3AR',
#  'SK16 5NS',
#  'NG15 7LY',
#  'HD3 3BG',
#  'NG31 8JW',
#  'CF72 8DW',
#  'SN2 2SY',
#  'WA7 2JW',
#  'MK11 1JL',
#  'CB24 5JT',
#  'PR2 9RF',
#  'PR26 7YB',
#  'ME15 9XA',
#  'FY6 0QB',
#  'TA2 6SY',
#  'SN4 8BB',
#  'LL14 1SU',
#  'DN2 5JP',
#  'NG5 8DR',
#  'BA12 9BY',
#  'HA3 6DD',
#  'CF72 9HZ',
#  'SS9 5SY',
#  'TN4 0SY',
#  'CV12 9PH',
#  'AL4 0EH',
#  'LE3 0JR',
#  'RM5 3YL',
#  'CV32 7HN',
#  'DA1 1YD',
#  'BN13 1NN',
#  'SE6 4EW',
#  'NG21 9DL',
#  'CW2 8AN',
#  'LS16 5NE',
#  'PL7 4ET',
#  'B25 8SP',
#  'B43 7RG',
#  'BH24 1NF',
#  'BN3 4GN',
#  'ME3 7PX',
#  'NG9 2BW',
#  'LS28 6BG',
#  'EX16 6HH',
#  'TA21 8EP',
#  'S11 8ZB',
#  'N22 6NP',
#  'MK42 9NQ',
#  'PE2 9PS',
#  'BR3 3QG',
#  'WV8 1SW',
#  'BN1 4QD',
#  'LS17 6JS',
# ...

# %%
list(pc['postcode'])
# Out:
# ['ZE1 0AA',
#  'ZE1 0AB',
#  'ZE1 0AD',
#  'ZE1 0AE',
#  'ZE1 0AF',
#  'ZE1 0AG',
#  'ZE1 0AH',
#  'ZE1 0AJ',
#  'ZE1 0AL',
#  'ZE1 0AN',
#  'ZE1 0AP',
#  'ZE1 0AQ',
#  'ZE1 0AR',
#  'ZE1 0AS',
#  'ZE1 0AT',
#  'ZE1 0AU',
#  'ZE1 0AW',
#  'ZE1 0AX',
#  'ZE1 0AZ',
#  'ZE1 0BA',
#  'ZE1 0BB',
#  'ZE1 0BD',
#  'ZE1 0BE',
#  'ZE1 0BF',
#  'ZE1 0BG',
#  'ZE1 0BH',
#  'ZE1 0BJ',
#  'ZE1 0BL',
#  'ZE1 0BN',
#  'ZE1 0BP',
#  'ZE1 0BQ',
#  'ZE1 0BR',
#  'ZE1 0BS',
#  'ZE1 0BT',
#  'ZE1 0BU',
#  'ZE1 0BW',
#  'ZE1 0BX',
#  'ZE1 0BY',
#  'ZE1 0BZ',
#  'ZE1 0DA',
#  'ZE1 0DB',
#  'ZE1 0DD',
#  'ZE1 0DE',
#  'ZE1 0DG',
#  'ZE1 0DH',
#  'ZE1 0DJ',
#  'ZE1 0DL',
#  'ZE1 0DP',
#  'ZE1 0DQ',
#  'ZE1 0DR',
#  'ZE1 0DS',
#  'ZE1 0DT',
#  'ZE1 0DU',
#  'ZE1 0DW',
#  'ZE1 0DX',
#  'ZE1 0EA',
#  'ZE1 0EB',
#  'ZE1 0ED',
#  'ZE1 0EE',
#  'ZE1 0EF',
#  'ZE1 0EG',
#  'ZE1 0EH',
#  'ZE1 0EJ',
#  'ZE1 0EL',
#  'ZE1 0EN',
#  'ZE1 0EP',
#  'ZE1 0EQ',
#  'ZE1 0ER',
#  'ZE1 0ES',
#  'ZE1 0ET',
#  'ZE1 0EU',
# ...

# %%
complete = pd.merge(pc,pp,on="postcode",how="inner")

# %%
datasets.load_pricepaid()
# Out:
# Loading price data.
# Using presampled dataset.
# Loaded property prices.
#       Unnamed: 0   price              date  postcode type      seconds   years
# 0              0   18500  1995-01-31 00:00   TQ1 1RY    F  791510400.0  1995.0
# 1              1   73450  1995-10-09 00:00   L26 7XJ    D  813193200.0  1995.0
# 2              2   59000  1995-03-31 00:00  BH12 2AE    D  796604400.0  1995.0
# 3              3   31000  1995-12-04 00:00  IP13 0DR    D  818035200.0  1995.0
# 4              4   95000  1995-09-22 00:00  WS14 0BE    D  811724400.0  1995.0
# 5              5   45450  1995-02-28 00:00   S42 5GA    S  793929600.0  1995.0
# 6              6   96000  1995-10-27 00:00  KT17 2DU    S  814752000.0  1995.0
# 7              7   30000  1995-11-28 00:00  WS10 9LD    S  817516800.0  1995.0
# 8              8  425000  1995-03-31 00:00  KT11 1HP    D  796604400.0  1995.0
# 9              9   89995  1995-06-30 00:00   WF6 2TT    D  804466800.0  1995.0
# ...

# %%
datasets.load_postcode()
# Out:
#      postcode  easting  northing
# 0     ZE1 0AA   447759   1141280
# 1     ZE1 0AB   447830   1141252
# 2     ZE1 0AD   447759   1141280
# 3     ZE1 0AE   447793   1141217
# 4     ZE1 0AF   447974   1141186
# 5     ZE1 0AG   447867   1141189
# 6     ZE1 0AH   448000   1141073
# 7     ZE1 0AJ   447780   1141257
# 8     ZE1 0AL   447818   1141186
# 9     ZE1 0AN   447966   1141213
# 10    ZE1 0AP   448026   1141143
# 11    ZE1 0AQ   447830   1141090
# 12    ZE1 0AR   447811   1141051
# 13    ZE1 0AS   447851   1140983
# 14    ZE1 0AT   447691   1140992
# 15    ZE1 0AU   447935   1141182
# 16    ZE1 0AW   447951   1141139
# 17    ZE1 0AX   447849   1140867
# 18    ZE1 0AZ   447408   1141463
# 19    ZE1 0BA   447984   1141037
# 20    ZE1 0BB   448173   1140902
# 21    ZE1 0BD   447729   1141262
# 22    ZE1 0BE   447711   1141124
# 23    ZE1 0BF   447771   1141219
# 24    ZE1 0BG   448104   1141135
# 25    ZE1 0BH   448031   1141020
# 26    ZE1 0BJ   447685   1141214
# ...
