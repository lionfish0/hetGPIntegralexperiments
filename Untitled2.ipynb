# %%
cd ~
# Out:
# /home/ubuntu

# %%
# !grep 'Running gradients_X' * -R
# Out:
# grep: anaconda3/pkgs/matplotlib-3.0.3-py37h5429711_0/lib/libtcl.so: No such file or directory
# grep: anaconda3/pkgs/matplotlib-3.0.3-py37h5429711_0/lib/libtk.so: No such file or directory
# Binary file hetMOGPintegral/GPy/GPy/kern/src/__pycache__/multidim_integral_kernel.cpython-36.pyc matches
# Binary file hetMOGPintegral/GPy/GPy/kern/src/__pycache__/multidim_integral_kernel.cpython-37.pyc matches
# hetMOGPintegral/GPy/GPy/kern/src/multidim_integral_kernel.py:        print("Running gradients_X")
# hetMOGPintegral/hetGPIntegralexperiments/Grad Checking.ipynb:      "Running gradients_X\n",
# hetMOGPintegral/hetGPIntegralexperiments/Grad Checking.ipynb:      "Running gradients_X\n",
# hetMOGPintegral/hetGPIntegralexperiments/Grad Checking.ipynb:      "Running gradients_X\n",
# hetMOGPintegral/hetGPIntegralexperiments/Grad Checking.ipynb:      "Running gradients_X\n",
# hetMOGPintegral/hetGPIntegralexperiments/Grad Checking.ipynb:      "Running gradients_X\n",
# ...

# %%
import dp4gp.datasets as datasets
pcs = datasets.load_postcode()

# %%
import pandas as pd

# %%
pcs[pcs['postcode']=='S6 3EF']
# Out:
# Empty DataFrame
# Columns: [postcode, easting, northing]
# Index: []

# %%
# !grep 'S6  3AF' Data/CSV/s.csv
# Out:
# "S6  3AF",10,434907,388271,"E92000001","E19000001","E18000003","","E08000019","E05010862"

# %%
pps = datasets.load_pricepaid(since=2015)
# Out:
# Loading price data.
# Using presampled dataset.
# Loaded property prices.

# %%
pps['postcode'][0::1000].str.replace(' ','').values
# Out:
# array(['BH13EF', 'HU181UA', 'MK437HP', ..., 'MK410DN', 'RG404UQ',
#        'TS148ED'], dtype=object)

# %%
pcs['postcode'][0::1000].str.replace(' ','').values
# Out:
# array(['TF11AA', 'TF17FA', 'TF119HR', ..., 'IP45RB', 'IP68TZ', 'IP83EA'],
#       dtype=object)
